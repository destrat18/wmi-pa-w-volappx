# %%
import pandas as pd
from ast import literal_eval

# %% [markdown]
# # Manual Functions

# %%
df_gubpi = pd.read_csv("final_results/gubpi_manual.csv").sort_values('index')
df_volesti = pd.read_csv("final_results/volesti_manual.csv").sort_values('index')
df_latte = pd.read_csv("final_results/latte_manual.csv").sort_values('index')
# df_psi = pd.read_csv("final_results/psi_manual.csv").sort_values('index')

# %%
pd.DataFrame({
    "Function": df_latte['formula'],
    "Gubpi": df_gubpi['output'].fillna(df_gubpi['error']),
    "Volesti": df_volesti['output'].fillna(df_volesti['error']),    
    "Latte": df_latte['output'].fillna(df_latte['error']),
    # "PsiSolver": df_psi['output'].fillna(df_psi['error'])
})
# Out:
#                                              Function  \
# 0                                               (x)*1
# 1                                            (x**2)*1
# 2                                            (x**3)*1
# 3                             (x**3 + x**2 + x + 1)*1
# 4                   (x**4 + x**3 + x**2 + x**1 + 1)*1
# 5                                               (1/x)
# 6                                           (1/(x+y))
# 7                                     (1/(x+y+(x*y)))
# 8                                         (1/(x+y+z))
# 9                                       (1/(x**2 -1))
# 10                            ((x**2+x+1)*1)/(x**3+1)
# 11                                (x*1/( 4.0 + x**2))
# 12                              ((x**3)*1/(4.0+x**2))
# 13                      (1/(4.0*x**2 + 9.0*x + 16.0))
# 14                          (1/( (4.0+x) * (x+9.0) ))
# 15                                     ((1/x)**(1/2))
# 16                                     ((1/x)**(1/3))
# 17                                 ((1/(x+1))**(1/2))
# 18                                (1/(x**2-1))**(1/2)
# 19                                   (1/(x+y))**(1/2)
# 20  ((x**2 + 2*y**2 + 3*y*x + x + 1)*1/(2*y**2 + y...
#
#                                           Gubpi                 Volesti  \
# 0      (0.4874999999999982, 0.5125000000000021)    (0.449084, 0.525333)
# 1     (0.3331775037124986, 0.33348919462330495)    (0.316554, 0.369804)
# 2    (0.24984827016353228, 0.25015176909508047)    (0.227981, 0.290891)
# 3       (2.0804081595527166, 2.086258920654905)      (2.02401, 2.39824)
# 4      (1.7791781814430736, 2.2864838808790706)      (2.13997, 2.60858)
# 5      (1.3967282610166747, 4.6586603061975875)       (4.4662, 5.00798)
# 6       (0.9016047404524042, 1.615011588400836)      (1.16331, 1.38399)
# 7      (0.7539674168856025, 1.4578981646335882)      (1.11946, 1.46136)
# 8     (0.39262436795817907, 1.4049346635027904)    (0.654199, 0.826891)
# 9      (0.9009516251293381, 2.1276139680177604)       (1.8216, 2.18702)
# 10     (1.4388604210338147, 1.4416370766047004)      (1.32471, 1.49071)
# 11   (0.11155755499270346, 0.11158599662725975)    (0.106456, 0.117152)
# 12  (0.05370219952965787, 0.053723596785845894)   (0.0513746, 0.062612)
# 13   (0.04718470633871178, 0.04718766828355469)  (0.0425337, 0.0495945)
# 14  (0.023556196040110826, 0.02355701823029768)  (0.0220972, 0.0255967)
# 15     (1.5129147687923277, 1.8208096162128216)                     N\S
# 16                                          N\S                     N\S
# 17     (0.8266129039158656, 0.8268254846338479)                     N\S
# 18     (1.0781575222777833, 1.1899655981254975)                     N\S
# 19      (0.9853092982735883, 1.211855650267777)                     N\S
# 20     (0.8104365442264316, 1.0673079216973802)      (0.86644, 1.01864)
#
#                                                 Latte
# 0                                             0.49995
# 1                                            0.333333
# 2                                                0.25
# 3                                            2.083333
# 4                                            2.283333
# 5                       Memory limit exceeded (maybe)
# 6                             Not a monomial: (x + y)
# 7                   Not a monomial: (x + y + (x * y))
# 8                         Not a monomial: (x + y + z)
# 9                  Not a monomial: (-1.0 + (x ^ 2.0))
# 10                  Not a monomial: (1.0 + (x ^ 3.0))
# 11                  Not a monomial: (4.0 + (x ^ 2.0))
# 12                  Not a monomial: (4.0 + (x ^ 2.0))
# 13  Not a monomial: (16.0 + (4.0 * (x ^ 2.0)) + (9...
# 14    Not a monomial: (36.0 + (x ^ 2.0) + (13.0 * x))
# 15                                                N\S
# 16                                                N\S
# 17                                                N\S
# 18                                                N\S
# 19                                                N\S
# 20  Not a monomial: (2.0 + y + (2.0 * (y ^ 2.0)) +...
